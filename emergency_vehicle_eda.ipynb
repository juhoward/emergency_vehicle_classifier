# %% [markdown]
# ## EDA
#
# The dataset description:
# - 1646 training images
# - 706 test images.
#
# The task will be binary image classification. The labels are:
# - 0 = non-emergency vehicle
# - 1 = emergency vehicle
#
# The classes are mildly unbalanced:
# - 59% non-emergency vehicles
# - 41% emergency vehicles
#
# Since this is a Kaggle dataset, the test images did not come with labels, so there is not validation split. The test set is an external validation set to be submitted to Kaggle.
#
# I will make a stratified validation split by randomly selecting 10% of the training images for the validation split.
# The slight imbalance of the training set will be maintained at 60:40 non-emergency:emergency.
# - non-emergency vehicles: 98
# - emergency vehicles: 66
# - total validation set size : 164

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd


data_dir = '/home/ubuntu/datasets/Emergency_Vehicles/'

train_labels = pd.read_csv(data_dir + 'train.csv')
test_labels = pd.read_csv(data_dir + 'test.csv')

train_labels.head()
# Out:
#   image_names  emergency_or_not
# 0    1503.jpg                 0
# 1    1420.jpg                 0
# 2    1764.jpg                 0
# 3    1356.jpg                 0
# 4    1117.jpg                 0

# %%
train_labels['emergency_or_not'].value_counts()
# Out:
# 0    965
# 1    681
# Name: emergency_or_not, dtype: int64

# %%
total = 965 + 681
print('Not Emergency: ', round(965 / total, 2), '\nEmergency: ', round(681 / total, 2))
# Out:
# Not Emergency:  0.59
# Emergency:  0.41

# %%
test_labels.head()
# Out:
#   image_names
# 0    1960.jpg
# 1     668.jpg
# 2    2082.jpg
# 3     808.jpg
# 4    1907.jpg

# %%
non_em = round(164 * .6, 0)
em = round(164 *.4, 0)
print('validation set univariate statistics', 
'\nnon-emergency vehicles: ', non_em,
'\nemergency vehicles: ', em,
'\nvalidation set size: ', non_em + em)
# Out:
# validation set univariate statistics
# non-emergency vehicles:  98.0
# emergency vehicles:  66.0
# validation set size:  164.0

# %% [markdown]
# ## Dataset Class

# %%
from torch.utils.data import Dataset
import matplotlib.pyplot as plt
# optional image reader
# from torchvision.io import read_image
from PIL import Image
import pandas as pd
import glob
import os
import numpy as np



class Emergency_Vehicles(Dataset):
    def __init__(self, data_dir, split, batch_size = 32,transform=None, 
    target_transform=None):
        self.data_dir = data_dir
        self.train_labels = pd.read_csv(data_dir + 'train.csv')
        self.val_labels = pd.read_csv(data_dir + 'val.csv')
        self.train_imgs = glob.glob(data_dir + 'train/' + '*.jpg')
        self.test_imgs = glob.glob(data_dir + 'test/' + '*.jpg')
        self.val_imgs = glob.glob(data_dir + 'val/' + '*.jpg')
        self.transform = transform
        self.target_transform = target_transform
        self.split = split

    def __len__(self):
        ''' test images are not labeled'''
        return {'train': len(self.train_imgs), 'test': len(self.test_imgs)}

    def __getitem__(self, idx):
        if self.split == 'train':
            img_path = os.path.join(self.data_dir, self.split, self.train_labels.iloc[idx, 0])
            label = self.train_labels.iloc[idx, 1]
        else:
            img_path = os.path.join(self.data_dir, self.split, self.val_labels.iloc[idx, 1])
            label = self.val_labels.iloc[idx, 2]
        image = Image.open(img_path)
        
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

dataset = Emergency_Vehicles(data_dir, 'train')
idx = 42
img, label = dataset[idx]
# if using read_image, transform to channels last for plotting
# img = np.array(img)
# img = np.moveaxis(img, 0, -1)

plt.imshow(img)
plt.title(label)
plt.show()

# %% [markdown]
# ## Splitting The Data
#
# As of 7-28-22, the best course of action to take advantage of pytorch dataloading functions is to re-structure the dataset so that the directory names contain the labels (emergency, non-emergency). Most Pytorch helper functions assume datasets are organized this way.
#
# I will use the csv files that I created when I split the data to copy the images rather than move them, creating a new version of the dataset just in case something goes wrong. Version 2 of the dataset will be stored in a directory called dataset_v2.
#
# ### Old split_data function
#
# I will modify the split_data function to create a new restructure function that will copy the images to the new directories.

# %%
def split_data(data_labels, split_ratio, stratification=[.6, .4]):
    ''' takes the labels file and outputs two dataframes representing the 
        validation set. 
    '''
    np.random.seed(42)
    train = data_labels
    size = len(data_labels)
    sample_sizes = [int(size * split_ratio * s) for s in stratification]

    # get indices of non-emergency and emergency labels
    non_emergency = data_labels[data_labels['emergency_or_not'] == 0 ].index
    emergency = data_labels[data_labels['emergency_or_not'] == 1 ].index
    print('non-emergency: ', len(non_emergency), '\nemergency: ', len(emergency))
    output = []
    for idx in range(2):
        if idx == 0:
            # randomly sample ~60% of indices
            idxs = np.random.choice(non_emergency, sample_sizes[idx])
            # store rows
            output.append(data_labels.iloc[idxs])
            # remove rows from training set
            train = train.drop(idxs, axis=0)
        else:
            # randomly sample ~ 40% of indices
            idxs = np.random.choice(emergency, sample_sizes[idx])
            output.append(data_labels.iloc[idxs])
            # remove indices
            train = train.drop(idxs, axis=0)
    val = pd.concat(output, axis=0)
    # sometimes there are duplicates
    val = val.drop_duplicates()
    return train, val



dfs = split_data(dataset.train_labels, .10)
for df in dfs:
    print(len(df))
    print(df.head())
# Out:
# non-emergency:  965
# emergency:  681
# 1495
#   image_names  emergency_or_not
# 0    1503.jpg                 0
# 2    1764.jpg                 0
# 3    1356.jpg                 0
# 4    1117.jpg                 0
# 5      45.jpg                 1
# 151
#      image_names  emergency_or_not
# 163     1159.jpg                 0
# 746     1942.jpg                 0
# 1484    1661.jpg                 0
# 449     1920.jpg                 0
# 173     2016.jpg                 0

# %% [markdown]
# ## Move the Validation images out of the dataset
#
# There may be duplicate values in the val dataset? Each image the code below states is not found is actually in the val directory

# %%
# check for duplicates in validation set
print(len(dfs[1]))
print(len(dfs[1].drop_duplicates()))
# Out:
# 151
# 151

# %%
names = ['train_2.csv', 'val.csv']
os.makedirs(data_dir + 'val/', exist_ok=True)

for idx, df in enumerate(dfs):
    df.to_csv(data_dir + names[idx])
    if idx == 1:
        for img in df['image_names']:
            origin = data_dir + 'train/' + img
            
            destination = data_dir + 'val/' + img
            try:
                os.rename(origin, destination)
            except FileNotFoundError as e:
                print(e) 
                continue
# Out:
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1159.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1159.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1942.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1942.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1661.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1661.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1920.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1920.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2016.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2016.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1347.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1347.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1015.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1015.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1231.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1231.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1253.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1253.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2102.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2102.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1533.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1533.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1173.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1173.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1476.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1476.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2116.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2116.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1727.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1727.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1564.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1564.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1259.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1259.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1631.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1631.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1417.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1417.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1083.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1083.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1122.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1122.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1052.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1052.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1365.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1365.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1120.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1120.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1961.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1961.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1855.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1855.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1799.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1799.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2046.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2046.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2263.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2263.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1515.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1515.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1086.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1086.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1755.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1755.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2167.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2167.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2319.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2319.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1336.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1336.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1427.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1427.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2346.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2346.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1695.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1695.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1425.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1425.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1331.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1331.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2249.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2249.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1633.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1633.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1066.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1066.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1550.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1550.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1348.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1348.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1890.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1890.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1632.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1632.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2135.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2135.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1858.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1858.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1555.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1555.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1479.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1479.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2283.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2283.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2087.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2087.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1154.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1154.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1481.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1481.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1326.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1326.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1300.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1300.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2222.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2222.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1438.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1438.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1116.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1116.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1539.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1539.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1569.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1569.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1826.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1826.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1007.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1007.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1994.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1994.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2105.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2105.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1823.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1823.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1433.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1433.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1250.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1250.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1923.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1923.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1435.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1435.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1623.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1623.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2165.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2165.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1074.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1074.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1026.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1026.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1046.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1046.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1982.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1982.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1297.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1297.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1619.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1619.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1850.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1850.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2171.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2171.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1129.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1129.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1464.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1464.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1420.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1420.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1345.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1345.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1252.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1252.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1471.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1471.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1148.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1148.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1704.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1704.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1358.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1358.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2003.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/2003.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1626.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/1626.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/773.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/773.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/329.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/329.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/370.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/370.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/112.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/112.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/531.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/531.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/657.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/657.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/890.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/890.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/375.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/375.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/594.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/594.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/359.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/359.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/856.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/856.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/10.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/10.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/326.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/326.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/716.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/716.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/114.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/114.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/942.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/942.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/513.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/513.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/352.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/352.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/358.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/358.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/340.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/340.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/52.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/52.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/481.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/481.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/200.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/200.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/444.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/444.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/576.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/576.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/905.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/905.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/726.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/726.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/959.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/959.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/852.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/852.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/459.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/459.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/735.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/735.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/898.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/898.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/448.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/448.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/412.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/412.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/549.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/549.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/37.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/37.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/692.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/692.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/660.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/660.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/331.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/331.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/365.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/365.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/396.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/396.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/501.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/501.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/35.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/35.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/222.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/222.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/369.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/369.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/488.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/488.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/397.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/397.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/436.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/436.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/754.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/754.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/708.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/708.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/223.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/223.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/778.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/778.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/883.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/883.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/568.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/568.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/524.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/524.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/142.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/142.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/313.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/313.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/614.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/614.jpg'
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/919.jpg' -> '/home/ubuntu/datasets/Emergency_Vehicles/val/919.jpg'

# %%
print(len(dfs[1]))
print(len(os.listdir(data_dir + 'val')))
print(len(np.unique(dfs[1]['image_names'])))
# Out:
# 151
# 151
# 151

# %% [markdown]
# ## Restructure function
#
# The restructure function was successful with most images, which doesn't  appear to be in the training folder. This image was already found in the val directory and was copied into the val folder in the new restructured dataset.

# %%
data_dir = '/home/ubuntu/datasets/Emergency_Vehicles/'

train_labels = pd.read_csv(data_dir + 'train.csv')
val_labels = pd.read_csv(data_dir + 'val.csv')

val_labels.head()
# Out:
#    Unnamed: 0 image_names  emergency_or_not
# 0         163    1159.jpg                 0
# 1         746    1942.jpg                 0
# 2        1484    1661.jpg                 0
# 3         449    1920.jpg                 0
# 4         173    2016.jpg                 0

# %%
import shutil

def restructure(labels_files:dict()):
    ''' takes the pandas labels dataframes, creates a new directory structure
        and copies images to the new directories using their labels. 
    '''
    data_dir = '/home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/'
    
    print('reading labels files...')
    for split in ['train', 'val']:
        data_labels = labels_files[split]
        # get indices of non-emergency and emergency labels
        non_emergency = data_labels[data_labels['emergency_or_not'] == 0 ].index
        emergency = data_labels[data_labels['emergency_or_not'] == 1 ].index
        idx_holder = {'emergency': emergency, 'non-emergency':non_emergency}
        print(split)
        print('non-emergency: ', len(non_emergency), '\nemergency: ', len(emergency))
        for lab in ['emergency', 'non-emergency']:

            # select vehicles based on their label
            filtered = data_labels.iloc[idx_holder[lab]]
            print(f'Copying {len(filtered)} {lab} images...')
            origin = '/home/ubuntu/datasets/Emergency_Vehicles/' + split
            print(data_dir + split + '/' + lab)
            os.makedirs(data_dir + split + '/' + lab, exist_ok=True)
            for img in filtered['image_names']: # len(emergency)):
                        
                img_path = origin + '/' + img
                
                destination = data_dir + split + '/' + lab + '/' + img
                
                try:
                    shutil.copy(img_path, destination)
                except FileNotFoundError as e:
                    print(e) 
                    print(img_path, '\n', destination)
                    print()

labs = {'train':train_labels, 'val':val_labels}

restructure(labs)
# Out:
# reading labels files...
# train
# non-emergency:  965
# emergency:  681
# Copying 681 emergency images...
# /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/436.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/436.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/436.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/352.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/352.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/352.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/37.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/37.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/37.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/331.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/331.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/331.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/942.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/942.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/942.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/365.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/365.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/365.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/856.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/856.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/856.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/576.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/576.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/576.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/358.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/358.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/358.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/614.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/614.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/614.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/222.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/222.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/222.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/481.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/481.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/481.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/692.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/692.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/692.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/905.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/905.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/905.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/513.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/513.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/513.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/329.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/329.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/329.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/326.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/326.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/326.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/660.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/660.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/660.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/370.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/370.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/370.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/778.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/778.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/778.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/10.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/10.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/10.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/754.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/754.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/754.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/549.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/549.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/549.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/142.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/142.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/142.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/375.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/375.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/375.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/112.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/112.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/112.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/531.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/531.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/531.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/898.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/898.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/898.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/594.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/594.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/594.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/359.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/359.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/359.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/52.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/52.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/52.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/448.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/448.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/448.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/716.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/716.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/716.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/852.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/852.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/852.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/223.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/223.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/223.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/708.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/708.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/708.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/501.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/501.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/501.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/735.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/735.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/735.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/657.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/657.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/657.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/568.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/568.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/568.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/890.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/890.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/890.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/444.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/444.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/444.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/919.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/919.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/919.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/412.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/412.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/412.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/114.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/114.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/114.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/726.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/726.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/726.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/396.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/396.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/396.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/340.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/340.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/340.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/369.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/369.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/369.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/883.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/883.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/883.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/773.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/773.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/773.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/313.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/313.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/313.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/35.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/35.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/35.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/524.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/524.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/524.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/959.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/959.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/959.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/488.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/488.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/488.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/397.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/397.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/397.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/200.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/200.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/200.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/459.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/459.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/emergency/459.jpg
#
# Copying 965 non-emergency images...
# /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1420.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1420.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1420.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1994.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1994.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1994.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1231.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1231.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1231.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1336.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1336.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1336.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1619.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1619.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1619.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2249.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2249.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2249.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1347.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1347.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1347.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2171.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2171.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2171.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1727.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1727.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1727.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1623.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1623.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1623.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1259.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1259.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1259.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1159.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1159.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1159.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1471.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1471.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1471.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2016.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2016.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2016.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2102.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2102.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2102.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1083.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1083.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1083.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1755.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1755.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1755.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1116.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1116.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1116.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1632.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1632.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1632.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2263.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2263.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2263.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1850.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1850.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1850.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1173.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1173.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1173.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2105.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2105.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2105.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2087.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2087.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2087.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1427.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1427.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1427.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1920.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1920.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1920.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1539.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1539.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1539.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1086.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1086.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1086.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1052.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1052.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1052.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2319.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2319.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2319.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1007.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1007.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1007.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1476.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1476.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1476.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1435.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1435.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1435.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1120.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1120.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1120.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1433.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1433.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1433.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2165.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2165.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2165.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1564.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1564.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1564.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2046.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2046.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2046.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1569.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1569.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1569.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1345.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1345.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1345.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1626.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1626.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1626.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1855.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1855.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1855.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1026.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1026.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1026.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1942.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1942.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1942.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1074.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1074.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1074.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2116.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2116.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2116.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2167.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2167.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2167.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1533.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1533.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1533.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1331.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1331.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1331.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1550.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1550.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1550.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1358.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1358.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1358.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1326.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1326.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1326.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1961.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1961.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1961.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1481.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1481.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1481.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1046.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1046.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1046.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1633.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1633.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1633.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1425.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1425.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1425.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1464.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1464.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1464.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1555.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1555.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1555.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1250.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1250.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1250.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1252.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1252.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1252.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2283.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2283.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2283.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1826.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1826.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1826.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1253.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1253.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1253.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2222.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2222.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2222.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1122.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1122.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1122.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1417.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1417.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1417.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1066.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1066.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1066.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1858.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1858.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1858.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1348.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1348.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1348.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1015.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1015.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1015.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2003.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2003.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2003.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2346.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2346.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2346.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1365.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1365.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1365.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1148.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1148.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1148.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1982.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1982.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1982.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1823.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1823.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1823.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1890.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1890.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1890.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1799.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1799.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1799.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1300.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1300.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1300.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1704.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1704.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1704.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1154.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1154.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1154.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1438.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1438.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1438.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1695.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1695.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1695.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1661.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1661.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1661.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1631.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1631.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1631.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1479.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1479.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1479.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1923.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1923.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1923.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1129.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1129.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1129.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1297.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1297.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1297.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/1515.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/1515.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/1515.jpg
#
# [Errno 2] No such file or directory: '/home/ubuntu/datasets/Emergency_Vehicles/train/2135.jpg'
# /home/ubuntu/datasets/Emergency_Vehicles/train/2135.jpg
#  /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/train/non-emergency/2135.jpg
#
# val
# non-emergency:  92
# emergency:  59
# Copying 59 emergency images...
# /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/val/emergency
# Copying 92 non-emergency images...
# /home/ubuntu/datasets/Emergency_Vehicles/dataset_v2/val/non-emergency

# %%
from torchvision import transforms as T
from torchvision import datasets

def data_transformers(split:str):
    # using ImageNet mean and standard deviations to normalize images
    mu = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    # training images will be randomly cropped and horizontally flipped
    # validation images will only be normalized
    data_transforms = {'train': T.Compose([
        T.RandomResizedCrop(224),
        T.RandomHorizontalFlip(),
        T.ToTensor(),
        T.Normalize(mu, std)
        ]),
        'val': T.Compose([
        T.Resize(256),
        T.CenterCrop(224),
        T.ToTensor(),
        T.Normalize(mu, std)
        ])}
    return data_transforms[split]

train_trans = data_transformers('train')
val_trans = data_transformers('val')

# %%
train = Emergency_Vehicles(data_dir, 'train', transform=train_trans)
val = Emergency_Vehicles(data_dir, 'val', transform=val_trans)
idx = 42
train_ex= train[idx]
val_ex = val[idx]

examples = [train_ex, val_ex]


img = np.array(examples[0][0])
img = np.moveaxis(img, 0, -1)
plt.subplot(1,2,1)
plt.imshow(img)
plt.title(examples[0][1])
img = np.array(examples[1][0])
img = np.moveaxis(img, 0, -1)
plt.subplot(1,2,2)
plt.imshow(img)
plt.title(examples[1][1])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
